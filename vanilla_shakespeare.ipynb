# %% [markdown]
# <a href="https://colab.research.google.com/github/dilettamilana/LLMtest/blob/main/vanilla_shakespeare.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/karpathy/nanoGPT
# Out:
# Cloning into 'nanoGPT'...
# remote: Enumerating objects: 649, done.
# remote: Total 649 (delta 0), reused 0 (delta 0), pack-reused 649
# Receiving objects: 100% (649/649), 936.45 KiB | 24.64 MiB/s, done.
# Resolving deltas: 100% (371/371), done.

# %%
pip install tiktoken transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 33.1 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.
# ...

# %%
# !cd ./nanoGPT/data/shakespeare/ && python prepare.py
# Out:
# train has 301,966 tokens
# val has 36,059 tokens

# %%
#--init_from=gpt2
# !cd ./nanoGPT/ && python train.py --dtype=float16 --dataset=shakespeare --compile=False --n_layer=4 --n_head=4 --n_embd=64 --block_size=64 --batch_size=8  --eval_interval=100 --eval_iters=100 --max_iters=400 --bias=True --always_save_checkpoint=True
# Out:
# Overriding: dtype = float16
# Overriding: dataset = shakespeare
# Overriding: compile = False
# Overriding: n_layer = 4
# Overriding: n_head = 4
# Overriding: n_embd = 64
# Overriding: block_size = 64
# Overriding: batch_size = 8
# Overriding: eval_interval = 100
# Overriding: eval_iters = 100
# Overriding: max_iters = 400
# Overriding: bias = True
# tokens per iteration will be: 20,480
# Initializing a new model from scratch
# defaulting to vocab_size of GPT-2 to 50304 (50257 rounded up for efficiency)
# number of parameters: 3.42M
# num decayed parameter tensors: 18, with 3,420,160 parameters
# num non-decayed parameter tensors: 34, with 3,456 parameters
# using fused AdamW: True
# step 0: train loss 10.8205, val loss 10.8211
# iter 0: loss 10.8249, time 1971.85ms, mfu -100.00%
# iter 1: loss 10.8255, time 302.45ms, mfu -100.00%
# iter 2: loss 10.8231, time 308.99ms, mfu -100.00%
# iter 3: loss 10.8023, time 319.29ms, mfu -100.00%
# ...

# %%
# !cd ./nanoGPT && python sample.py --dtype=float16 --num_samples=1 --max_new_tokens=1000 --start="to"
# Out:
# Overriding: dtype = float16
# Overriding: num_samples = 1
# Overriding: max_new_tokens = 1000
# Overriding: start = to
# number of parameters: 3.42M
# No meta.pkl found, assuming GPT-2 encodings...
# to d timeM-- down's they have we beING so his allAnd for and heartG husband shouldVOL soul deadIZINC is lord here lords!ShetP tell good an they butINCIUCAB for manLetFirst sweet good lifele be did whoEL ED should an will they stand whose takeay shall my husband man mustIN mine itESO lordsAD shall or lordest from hath men be whichIS but with done wereAB name areBR soulBeG
#  tell lords we deathYES our dead was sayHe own's uponUCWhatIs both best
# Ofre wife theyLeten
# ...

# %%
#--init_from=gpt2
# !cd ./nanoGPT/ && python train.py --dtype=float16 --dataset=shakespeare --compile=False --n_layer=4 --n_head=4 --n_embd=64 --block_size=64 --batch_size=8  --eval_interval=100 --eval_iters=100 --max_iters=2500 --bias=True --always_save_checkpoint=True
# Out:
# Overriding: dtype = float16
# Overriding: dataset = shakespeare
# Overriding: compile = False
# Overriding: n_layer = 4
# Overriding: n_head = 4
# Overriding: n_embd = 64
# Overriding: block_size = 64
# Overriding: batch_size = 8
# Overriding: eval_interval = 100
# Overriding: eval_iters = 100
# Overriding: max_iters = 2500
# Overriding: bias = True
# Overriding: always_save_checkpoint = True
# tokens per iteration will be: 20,480
# Initializing a new model from scratch
# defaulting to vocab_size of GPT-2 to 50304 (50257 rounded up for efficiency)
# number of parameters: 3.42M
# num decayed parameter tensors: 18, with 3,420,160 parameters
# num non-decayed parameter tensors: 34, with 3,456 parameters
# using fused AdamW: True
# step 0: train loss 10.8205, val loss 10.8211
# iter 0: loss 10.8249, time 2370.42ms, mfu -100.00%
# iter 1: loss 10.8255, time 417.77ms, mfu -100.00%
# iter 2: loss 10.8231, time 459.13ms, mfu -100.00%
# iter 3: loss 10.8023, time 338.02ms, mfu -100.00%
# ...

# %%
# !cd ./nanoGPT && python sample.py --dtype=float16 --num_samples=1 --max_new_tokens=1000 --start="to be"
# Out:
# Overriding: dtype = float16
# Overriding: num_samples = 1
# Overriding: max_new_tokens = 1000
# Overriding: start = to be
# number of parameters: 3.42M
# No meta.pkl found, assuming GPT-2 encodings...
# to be so much consul.
#
# MENENIUS:
# I have ever.
#
# VOLUMNIA:
# The queen he shall die!
#
# COMINIUS:
# No, no.
#
# CORIOLANUS:
# The news is an uncles will be gone to take
# The tribune with holy general's true.
#
# MENENIUS:
# Was she be seen a little heard of life:
# Ere it was aught from the city's body's voice
# In old friar's hands.
#
# AUFIDIUS:
# Let's a present rest,--Ah, for him: but
# Methinks I crave him then, though now appear
# That they, with the prince
# To bless the second deukes, and our course,
# That in this unwill them, and see him speak,
# That ever we would be so, but not so young;
# But, but to time may omit this light on's seem,
# To give us pardon with such a tale.
#
# QUEEN:
# And she shall be so, for for I say,
# Than I am a soldier of their own arms.
#
# ...
